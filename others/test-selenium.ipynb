# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait

browser = webdriver.Chrome('C:/Program Files/chromedriver_win32/chromedriver.exe')
try:
    browser.get('https://www.baidu.com')
    input = browser.find_element_by_id('kw')
    input.send_keys('Python')
    input.send_keys(Keys.ENTER)
    wait = WebDriverWait(browser, 10)
    wait.until(EC.presence_of_element_located((By.ID, 'content_left')))
    print(browser.current_url)
    print(browser.get_cookies())
    print(browser.page_source)
finally:
    browser.close()
# Out:
# https://www.baidu.com/s?ie=utf-8&f=8&rsv_bp=1&rsv_idx=1&tn=baidu&wd=Python&fenlei=256&rsv_pq=e6aa6d5100023416&rsv_t=f16chu%2FOxQGcO5A52oUvDXRWoLdZX5VwNs0Bx0ncKVv9Rj30SfekdorjmpE&rqlang=cn&rsv_enter=1&rsv_dl=tb&rsv_sug3=6&rsv_sug2=0&rsv_btype=i&inputT=157&rsv_sug4=157
# ...

# %%
from bs4 import BeautifulSoup
options = webdriver.ChromeOptions()
browser = webdriver.Chrome('C:/Program Files/chromedriver_win32/chromedriver.exe')
browser.get('https://www.researchgate.net/publication/26787109_The_urban_heat_island_and_its_impact_on_heat_waves_and_human_health_in_Shanghai?tdsourcetag=s_pcqq_aiomsg')   
#soup = BeautifulSoup(browser.page_source,'lxml')
button = browser.find_elements_by_class_name('nova-c-button')
button[0].click()
soup = BeautifulSoup(browser.page_source,'lxml')
#button[1].click()
#print(button)

# %%
title = []
for i in soup.find_all(class_='nova-e-link nova-e-link--color-inherit nova-e-link--theme-bare'):
    content = str(i.string)
    if len(content) > 30 and content is not None:
        title.append(content)
title
# Out:
# ['Influence of Urban Scale and Urban Expansion on the Urban Heat Island Effect in Metropolitan Areas: Case Study of Beijing-Tianjin-Hebei Urban Agglomeration',
#  'Intraurban social risk and mortality patterns during extreme heat events: A case study of Moscow',
#  'Îlots de Chaleur Urbains et Ville: La Perception des Habitants',
#  'Tree crowns and their associated summertime microclimatic adjustment and thermal comfort improvement in urban parks in a subtropical city of China',
#  'Multi-hazard climate risk projections for the United States',
#  'Surface Urban Heat Island in Middle City: Spatial and Temporal Characteristics',
#  'Socioeconomic level and associations between heat exposure and all-cause and cause-specific hospitalization in 1,814 Brazilian cities: A nationwide case-crossover study',
# ...

# %%
soup.find(class_='nova-e-link nova-e-link--color-inherit nova-e-link--theme-bare')
# Out:
# <a class="nova-e-link nova-e-link--color-inherit nova-e-link--theme-bare" href="profile/Jianguo_Tan2">Jianguo Tan</a>

# %%
'''
for i in soup.find_all(class_='nova-e-link nova-e-link--color-inherit nova-e-link--theme-bare'):
    if 'publication' in i['href']:
        content = str(i.string)
        print(content)
    elif ''
'''
title_info = []
for i in soup.find_all(class_='nova-e-link nova-e-link--color-inherit nova-e-link--theme-bare'):
    #content = str(i.string)
    if 'publication' in i['href']:
        title = i.string
        #print(title)
    author_list = i.find_all(class_='nova-v-person-inline-item__fullname')
    #if len(author) != 0:
        #author = author_list[0].string
    print(author)
    dict_row = {'title': title,  
                'author': author
    }
    title_info.append(dict_row)
#title_info
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %%
'publication' in 'publication/344416452_Intraurban_social_risk_and_mortality_patterns_during_extreme_heat_events_A_case_study_of_Moscow'
# Out:
# True

# %%
for i in soup.find_all(class_='nova-e-link nova-e-link--color-inherit nova-e-link--theme-bare'):
    print(i['href'])
# Out:
# profile/Jianguo_Tan2
# profile/Jianguo_Tan2
# scientific-contributions/Youfei-Zheng-2044639838
# scientific-contributions/Xu-Tang-2039914065
# scientific-contributions/Changyi-Guo-16021493
# https://www.researchgate.net/figure/Shanghai-within-China-and-the-spatial-distribution-of-11-weather-stations-across-Shanghai_fig1_26787109
# https://www.researchgate.net/figure/Shanghai-within-China-and-the-spatial-distribution-of-11-weather-stations-across-Shanghai_fig8_26787109
# https://www.researchgate.net/figure/Summary-statistics-of-excess-mortality-rate-and-mean-maximum-temperature-in-heat-waves_tbl1_26787109
# publication/344842510_Influence_of_Urban_Scale_and_Urban_Expansion_on_the_Urban_Heat_Island_Effect_in_Metropolitan_Areas_Case_Study_of_Beijing-Tianjin-Hebei_Urban_Agglomeration
# https://www.researchgate.net/profile/Mingxing_Chen
# https://www.researchgate.net/profile/Zhou_Yuan35
# https://www.researchgate.net/profile/Maogui_Hu
# ...

# %%
#nova-v-person-inline-item__fullname
for i in soup.find_all(class_='nova-o-stack__item publication-citations__item publication-citations__item--redesign'):
    author = i.find_all(class_='nova-v-person-inline-item__fullname')
    print(i)
    #if len(author) != 0:
        #print(author)
    #    author_name = author[0].string
    #    print(author_name)
# Out:
# <div class="nova-o-stack__item publication-citations__item publication-citations__item--redesign"><div class="nova-v-citation-item"><div class="nova-o-stack nova-o-stack--gutter-m nova-o-stack--spacing-none nova-o-stack--no-gutter-outside"><div class="nova-o-stack__item"><div class="nova-c-tooltip nova-c-tooltip--position-above-left nova-c-tooltip--elevation-none nova-c-tooltip--color-white nova-c-tooltip--spacing-m nova-c-tooltip--luminosity-medium nova-v-citation-item__context"><div class="nova-c-tooltip__body"><div class="nova-c-tooltip__body-content"><div class="nova-o-stack nova-o-stack--gutter-m nova-o-stack--spacing-none nova-o-stack--show-divider nova-o-stack--no-gutter-outside"><div class="nova-o-stack__item"><div class="nova-o-stack nova-o-stack--gutter-m nova-o-stack--spacing-none nova-o-stack--show-divider nova-o-stack--no-gutter-outside"><div class="nova-o-stack__item"><div class="nova-o-stack nova-o-stack--gutter-m nova-o-stack--spacing-none nova-o-stack--show-divider n
# ...

# %%
import pandas as pd
pd.DataFrame(title_info)
# Out:
#                                                  title author
# 0    [Influence of Urban Scale and Urban Expansion ...     []
# 1    [Influence of Urban Scale and Urban Expansion ...     []
# 2    [Influence of Urban Scale and Urban Expansion ...     []
# 3    [Influence of Urban Scale and Urban Expansion ...     []
# 4    [Influence of Urban Scale and Urban Expansion ...     []
# ..                                                 ...    ...
# 96   Fourth Assessment Report (AR4). Climate Change...     []
# 97   Fourth Assessment Report (AR4). Climate Change...     []
# 98   Fourth Assessment Report (AR4). Climate Change...     []
# 99   Fourth Assessment Report (AR4). Climate Change...     []
# 100  Fourth Assessment Report (AR4). Climate Change...     []
#
# [101 rows x 2 columns]

# %%
soup.find_all(class_='nova-o-stack__item publication-citations__item publication-citations__item--redesign')[0]
# Out:
# <div class="nova-o-stack__item publication-citations__item publication-citations__item--redesign"><div class="nova-v-citation-item"><div class="nova-o-stack nova-o-stack--gutter-m nova-o-stack--spacing-none nova-o-stack--no-gutter-outside"><div class="nova-o-stack__item"><div class="nova-c-tooltip nova-c-tooltip--position-above-left nova-c-tooltip--elevation-none nova-c-tooltip--color-white nova-c-tooltip--spacing-m nova-c-tooltip--luminosity-medium nova-v-citation-item__context"><div class="nova-c-tooltip__body"><div class="nova-c-tooltip__body-content"><div class="nova-o-stack nova-o-stack--gutter-m nova-o-stack--spacing-none nova-o-stack--show-divider nova-o-stack--no-gutter-outside"><div class="nova-o-stack__item"><div class="nova-o-stack nova-o-stack--gutter-m nova-o-stack--spacing-none nova-o-stack--show-divider nova-o-stack--no-gutter-outside"><div class="nova-o-stack__item"><div class="nova-o-stack nova-o-stack--gutter-m nova-o-stack--spacing-none nova-o-stack--show-divider n
# ...

# %%
for i in soup.find_all(class_='nova-o-stack__item publication-citations__item publication-citations__item--redesign'):
    for j in i.find_all(class_='nova-e-link nova-e-link--color-inherit nova-e-link--theme-bare'):
        print(j)
# Out:
# <a class="nova-e-link nova-e-link--color-inherit nova-e-link--theme-bare" href="publication/344842510_Influence_of_Urban_Scale_and_Urban_Expansion_on_the_Urban_Heat_Island_Effect_in_Metropolitan_Areas_Case_Study_of_Beijing-Tianjin-Hebei_Urban_Agglomeration">Influence of Urban Scale and Urban Expansion on the Urban Heat Island Effect in Metropolitan Areas: Case Study of Beijing-Tianjin-Hebei Urban Agglomeration</a>
# ...

# %%
for i, j in enumerate(soup.find_all(class_='nova-v-publication-item__body')):
    if i == 0:
        print(j)
# Out:
# <div class="nova-v-publication-item__body"><div class="nova-v-publication-item__stack nova-v-publication-item__stack--gutter-m"><div class="nova-v-publication-item__stack-item"><div class="nova-e-text nova-e-text--size-l nova-e-text--family-sans-serif nova-e-text--spacing-none nova-e-text--color-inherit nova-e-text--clamp-2 nova-v-publication-item__title"><a class="nova-e-link nova-e-link--color-inherit nova-e-link--theme-bare" href="publication/344842510_Influence_of_Urban_Scale_and_Urban_Expansion_on_the_Urban_Heat_Island_Effect_in_Metropolitan_Areas_Case_Study_of_Beijing-Tianjin-Hebei_Urban_Agglomeration">Influence of Urban Scale and Urban Expansion on the Urban Heat Island Effect in Metropolitan Areas: Case Study of Beijing-Tianjin-Hebei Urban Agglomeration</a></div></div><div class="nova-v-publication-item__stack-item"><div class="nova-v-publication-item__meta"><div class="nova-v-publication-item__meta-left"><span class="nova-e-badge nova-e-badge--color-green nova-e-badge--displ
# ...
